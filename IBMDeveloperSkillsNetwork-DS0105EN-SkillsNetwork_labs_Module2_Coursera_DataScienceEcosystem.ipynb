# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:24cfb7c9-b356-4274-8429-7f60b8ff9504.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.By including which tools and languages are used in Data Science. And some basic operation of notebook.

# %% [markdown]
# ![3-intro.png](attachment:61a1e8ea-460c-42b2-96a6-43cee307b59a.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python,
# 2. R,
# 3. JavaScript,
# 4. Scala,
# 5. Julia,
# 6. SQL, etc

# %% [markdown]
# ![4-dslanguages.png](attachment:0d5d03cd-e261-46ea-a58f-97c2b3d0f944.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. TensorFlow,
# 2. NumPy,
# 3. SciPy,
# 4. Pandas,
# 5. Matplotlib,
# 6. Keras,
# 7. SciKit-Learn,
# 8. PyTorch, etc.

# %% [markdown]
# ![5-dslibraries.png](attachment:295444a2-2dd0-4772-8256-0082440699d4.png)

# %% [markdown]
# Data Science tools
# | No. | Tools |
# | ------ | ------ |
# | 1 | Python |
# | 2 | R(studio) |
# | 3 | Apache Hadoop |
# | 4 | TensorFlow |
# | 5 | Jupyter |
# | 6 | Matplotlib |

# %% [markdown]
# ![6-dstools.png](attachment:afc20d9d-317b-4257-bb12-f9729adacbab.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
(25+5)*4-20
# Out:
# 100

# %% [markdown]
# ![7-introarithmetic.png](attachment:2885fbb4-c051-41c9-9c2d-1cefb86bdb7a.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:b716dff0-4c1b-4110-b286-7a91a7669c7b.png)

# %%
#This will convert 200 minutes to hours by diving by 60
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:46b4656e-be04-4772-9ac4-4849d26a0b63.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science.
# - List popular libraries for Data Science.
# - List popular tools for Data Science.
# - Basic Arithmetic operations.

# %% [markdown]
# ![10-objectives.png](attachment:bd4d9996-56ad-4ffa-94a0-5a2a319d5976.png)

# %% [markdown]
# ## Author
# Shubham Kumar

# %% [markdown]
# ![11-authordetails.png](attachment:9bc2c03b-c1fe-4267-9c12-4ed4074a9e2b.png)
